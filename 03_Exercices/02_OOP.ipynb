# %% [markdown]
# ## 1. Simple Person class
#
# Create a class `Person` with:
#
# * attributes: `name`, `age`
# * method: `introduce()` → prints a sentence with name and age

# %% [markdown]
# ## 2. Dog class
#
# Create a class `Dog` with:
#
# * attributes: `name`, `breed`
# * method: `bark()` → prints `"Woof!" + name`

# %% [markdown]
# ## 3. Rectangle class
#
# Create a class `Rectangle` with:
#
# * attributes: `width`, `height`
# * method: `area()` → returns area
# * method: `perimeter()` → returns perimeter

# %% [markdown]
# ## 4. Student class
#
# Create a class `Student` with:
#
# * attributes: `name`, `grades` (list)
# * method: `average()` → returns average grade

# %% [markdown]
# ## 5. Bank account
#
# Create a class `BankAccount` with:
#
# * attribute: `balance`
# * methods:
#
#   * `deposit(amount)`
#   * `withdraw(amount)`
#   * `show_balance()`

# %% [markdown]
# ## 6. Car class
#
# Create a class `Car` with:
#
# * attributes: `brand`, `speed`
# * methods:
#
#   * `accelerate(amount)`
#   * `brake(amount)`

# %% [markdown]
# ## 7. Counter class
#
# Create a class `Counter` with:
#
# * attribute: `value` (starts at 0)
# * methods:
#
#   * `increment()`
#   * `decrement()`
#   * `reset()`

# %% [markdown]
# ## 8. Book class
#
# Create a class `Book` with:
#
# * attributes: `title`, `author`, `pages`
# * method: `info()` → prints book details

# %% [markdown]
# ## 9. Temperature class
#
# Create a class `Temperature` with:
#
# * attribute: `celsius`
# * methods:
#
#   * `to_fahrenheit()`
#   * `is_hot()` → returns True if > 30°C

# %% [markdown]
# ## 10. Simple shopping item
#
# Create a class `Item` with:
#
# * attributes: `name`, `price`, `quantity`
# * method: `total_price()` → returns price × quantity
