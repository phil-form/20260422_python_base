# %% [markdown]
# # 🐼 Introduction to the Pandas Library — Exercises
#
# ## 1) Import the pandas library
#
# Import the pandas library.
#
# ---
#
# ## 2) Import the CSV file
#
# Load the CSV file into a DataFrame.
#
# ---
#
# ## 3) Display the first 5 rows
#
# Display the first 5 rows to check if the import is correct
# (function: `head()`).
#
# ---
#
# ## 4) Display the last 5 rows
#
# Display the last 5 rows (function: `tail()`).
#
# ---
#
# ## 5) Display information about the DataFrame
#
# Show:
#
# * number of rows and columns
# * number of NaN values
# * data types of each column
#   (method: `info()`)
#
# ---
#
# ## 6) Display the shape of the DataFrame
#
# Show the dimensions of the DataFrame (method: `shape`).
#
# ---
#
# ## 7) Display descriptive statistics
#
# Show descriptive statistics of the DataFrame.
#
# ---
#
# ## 8) Count missing values
#
# Count the number of null (NaN) values in the DataFrame.
#
# ---
#
# ## 9) Select the “Edition” column
#
# Select and display the `Edition` column in 2–3 different ways
# (Edition = Games).
#
# ---
#
# ## 10) Sort the “Name” column
#
# Select the `Name` column and display it sorted in alphabetical order.
#
# ---
#
# ## 11) Select multiple columns
#
# Select the columns:
#
# * Event
# * City
# * Name
# * Medal
#
# ---
#
# ## 12) Slice rows using iloc
#
# Slice rows from index 0 to 25 using `iloc`.
#
# ---
#
# ## 13) Filter Football discipline
#
# Filter the dataset for Football using **two different methods**.
#
# ---
#
# ## 14) Filter Summer season
#
# Filter rows where season is Summer and store them in a new variable called `summer`.
#
# ---
#
# ## 15) Filter Winter season
#
# Filter rows where season is Winter and store them in a new variable called `winter`.
#
# ---
#
# ## 16) Display unique sports
#
# Display all unique sports.
#
# ---
#
# ## 17) Filter athletes by name
#
# Filter rows where athlete names contain **“Owens” or “Jesse”** and store them in a new variable.
#
# ---
#
# ## 18) Count occurrences (Events for Owens/Jesse)
#
# Count occurrences in the `Event` column for Owens and Jesse
# (function: `value_counts()`).
#
# ---
#
# ## 19) Count men and women
#
# Count how many men and women are in the dataset
# (function: `value_counts()`).
#
# ---
#
# ## 20) Youngest athlete
#
# Find the youngest athlete.
#
# ---
#
# ## 21) Oldest athlete
#
# Find the oldest athlete.
#
# ---
#
# ## 22) Gold medal badminton (singles)
#
# Find athletes who won **Gold medals in singles badminton** over the years.
# Sort results alphabetically by athlete name.
#
# ---
#
# ## 23) Top 3 countries (1984–2016)
#
# Find the 3 countries with the most medals between 1984 and 2016.
#
# ---
#
# ## 24) Gender participation in 2016 Summer Olympics
#
# How many men and women participated in the 2016 Summer Olympics?
#
# ---
#
# ## 25) Medals for Belgium
#
# Display the number of medals for Belgium.
#
# ---
#
# ## 26) Belgium gold medal sports
#
# Which sports did Belgium win Gold medals in?
#
# ---
#
# ## 27) Best medal years for Belgium
#
# Which years did Belgium win the most medals?
#
# ---
#
# ## 28) Female gold medalists in athletics
#
# Display female gold medalists in athletics with:
#
# * Year
# * Event
# * Name
# * Country
#
# ---
#
# ## 29) Number of sports per year
#
# How many different sports were played each year?
#
# ---
#
# ## 30) Top 15 countries by medals
#
# Find the top 15 countries with the most total medals.
#
# ---
#
# ## 31) Best countries per sport
#
# Which countries win the most medals for each sport?
#
# ---
#
# ## 32) Cold War efficiency (1952–1988)
#
# Which countries were the most efficient during the Cold War period (1952–1988),
# i.e., the most medals per number of athletes sent?
#
# ---
