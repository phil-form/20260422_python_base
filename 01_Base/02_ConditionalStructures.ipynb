# %%
A = 3
B = 9
C = False
D = not C


if A == 3:
    print("A is 3")
else:
    print("A is not 3")
# Out:
# A is 3

# %%
A = 8

if A == 3:
    print("A is 3")
else:
    print("A is not 3")
# Out:
# A is not 3

# %%
A = 3
B = 9
C = False
D = not C

if A == 3 and B != 9:
    print("Something is")
elif A == 3 and B == 9:
    print("A is 3, B == 9")
else:
    print("unknown state")
# Out:
# A is 3, B == 9

# %%
if A == 3 and B == 9:
    if C:
        print("A is 3, B == 9 and C is True")
    else:
        if D:
            print("A is 3, B == 9 and C is False, but D is True")
# Out:
# A is 3, B == 9 and C is False, but D is True
