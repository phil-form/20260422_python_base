# %% [markdown]
# # 2) Types

# %%
# Number types

# integer type
number = 1

# float type
number_flt = 1.2

# Boolean

bool_val = True
bool_val = False

# string types :
my_str = "my string content"

my_str = "my str with \"this is between quotes\""

multi_line_str = """My string on
multiple lines

I can keep going
...
..
...
..
"""

# Unicode str  (with a "u" in front of the opening " or ' )
my_unicode_str = u"my unicode string"

# %% [markdown]
# # Escape chars
#
# * \n => return to line
# * \r => return carrier  => return to line
# * \\ => print "\"
# * \" => print "
# * \' => print '

# %% [markdown]
# # Conversion

# %%
# Convert to integer

my_str = "65482"

my_int = int(my_str)
print(type(my_int))

my_float = float(my_str)
print(type(my_float))
my_float = float(my_int)
print(type(my_float))

as_str = str(my_int)
print(type(as_str))
print(my_int)
print(as_str)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# 65482
# 65482
